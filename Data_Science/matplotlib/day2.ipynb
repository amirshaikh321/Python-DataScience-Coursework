# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("Salary_dataset.csv")
df
# Out:
#     YearsExperience  Salary
# 0               1.2   39344
# 1               1.4   46206
# 2               1.6   37732
# 3               2.1   43526
# 4               2.3   39892
# 5               3.0   56643
# 6               3.1   60151
# 7               3.3   54446
# 8               3.3   64446
# 9               3.8   57190
# 10              4.0   63219
# 11              4.1   55795
# 12              4.1   56958
# 13              4.2   57082
# 14              4.6   61112
# 15              5.0   67939
# 16              5.2   66030
# 17              5.4   83089
# 18              6.0   81364
# 19              6.1   93941
# 20              6.9   91739
# 21              7.2   98274
# 22              8.0  101303
# 23              8.3  113813
# 24              8.8  109432
# 25              9.1  105583
# 26              9.6  116970
# 27              9.7  112636
# 28             10.4  122392
# 29             10.6  121873

# %%
x = df['YearsExperience']
y = df['Salary']

# %%
plt.bar(x,y,width=0.5)
plt.title("SALARY DATA", color='red')
plt.xlabel("Years Of Experience",color='blue')
plt.ylabel("Salary",color='blue')
plt.show()

# %%
Earth = [29,71]
plt.pie(Earth,colors=['green','skyblue'],labels=['LAND','WATER'])
plt.title('Earth Surface Coverage',fontdict={'size':'17','color':'red'})
plt.legend()
plt.show()
