# %%
with open('details.txt','r')as f:
    data = f.read()

print(data)
# Out:
# Amir
# Shaikh

# %%
f = open('details.txt','r')
l1 = f.readline()
print(l1)

l2 = f.readline()
print(l2)
# Out:
# Amir
#
# Shaikh

# %%
print(f.tell())
# Out:
# 14

# %%
f.seek(0)
print(f.tell())
# Out:
# 0

# %%
f = open('data1.txt','w')
f.write("Hello")
# Out:
# 5

# %%
f = open('data1.txt','a')
f.write('Python')
# Out:
# 6

# %%
f = open('data2.txt','x')
f.write('New File')
f.close()
