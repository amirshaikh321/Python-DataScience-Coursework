# %%
with open('details.txt','r')as f:
    data = f.read()

print(data)
# Out:
# Amir
# Shaikh
# PythonPythonPythonPythonPython

# %%
f = open('details.txt','r')
l1 = f.readline()
print(l1)

l2 = f.readline()
print(l2)
# Out:
# Amir
#
# Shaikh

# %%
print(f.tell())
# Out:
# 14

# %%
f.seek(0)
print(f.tell())
# Out:
# 0

# %%
f = open('data1.txt','w')
f.write("Hello")
# Out:
# 5

# %%
f = open('data1.txt','a')
f.write('Python')
# Out:
# 6

# %%
f = open('data2.txt','x')
f.write('New File')
f.close()
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 f = open('data2.txt','x')
#       2 f.write('New File')
#       3 f.close()
#
# File c:\Users\simra\miniconda3\Lib\site-packages\IPython\core\interactiveshell.py:327, in _modified_open(file, *args, **kwargs)
#     320 if file in {0, 1, 2}:
#     321     raise ValueError(
#     322         f"IPython won't let you open fd={file} by default "
#     323         "as it is likely to crash IPython. If you know what you are doing, "
#     324         "you can use builtins' open."
#     325     )
# --> 327 return io_open(file, *args, **kwargs)
#
# FileExistsError: [Errno 17] File exists: 'data2.txt'

# %%
f = open('data3.txt','w')
f.writelines(['hello\n','python'])
f.close()
